# %%
# %pip install implicit
# Out:
# Collecting implicit
#   Downloading implicit-0.7.2-cp310-cp310-manylinux2014_x86_64.whl.metadata (6.1 kB)
# Requirement already satisfied: numpy>=1.17.0 in /opt/conda/lib/python3.10/site-packages (from implicit) (1.26.4)
# Requirement already satisfied: scipy>=0.16 in /opt/conda/lib/python3.10/site-packages (from implicit) (1.11.4)
# Requirement already satisfied: tqdm>=4.27 in /opt/conda/lib/python3.10/site-packages (from implicit) (4.66.4)
# Requirement already satisfied: threadpoolctl in /opt/conda/lib/python3.10/site-packages (from implicit) (3.2.0)
# Downloading implicit-0.7.2-cp310-cp310-manylinux2014_x86_64.whl (8.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.9/8.9 MB 55.2 MB/s eta 0:00:00
# Installing collected packages: implicit
# Successfully installed implicit-0.7.2
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import numpy as np
from datetime import datetime

import scipy

# fix waring @ implicit/cpu/als.py:95
import threadpoolctl
threadpoolctl.threadpool_limits(1, "blas") 


from tqdm.auto import tqdm
tqdm.pandas()

# %%
train = (
    pd
    .read_csv('/kaggle/input/predicting-response/train.csv')
    .set_index('event_id', verify_integrity='unique')
    .drop(columns='Unnamed: 0')
)

display(train)
# Out:
#           session_id  recommendation_idx      timestamp  user_id  item_id  \
# event_id
# 0                  0                5709  1549316916000        0    10910
# 1                  0                5709  1549316916000        0    25996
# 2                  0                5709  1549316916000        0    13539
# 3                  0                5709  1549316916000        0    28273
# 4                  0                5709  1549316916000        0    11289
# ...              ...                 ...            ...      ...      ...
# 1414603        42152              112874  1555157492000    42152    11224
# 1414604        42152              112874  1555157492000    42152     6674
# 1414605        42152              112874  1555157492000    42152    28598
# 1414606        42152              112874  1555157492000    42152     4862
# 1414607        42152              112874  1555157492000    42152    21079
#
#           response
# event_id
# 0                0
# 1                0
# 2                0
# 3                0
# 4                0
# ...            ...
# 1414603          0
# 1414604          0
# 1414605          0
# 1414606          0
# 1414607          1
#
# [1414608 rows x 6 columns]

# %%
user_id_enc = {uid: i for i, uid in enumerate(train.user_id.sort_values().unique())}
item_id_enc = {iid: i for i, iid in enumerate(train.item_id.sort_values().unique())}

# %%
train['user_id_encoded'] = train.user_id.map(user_id_enc)
train['item_id_encoded'] = train.item_id.map(item_id_enc)
train
# Out:
#           session_id  recommendation_idx      timestamp  user_id  item_id  \
# event_id
# 0                  0                5709  1549316916000        0    10910
# 1                  0                5709  1549316916000        0    25996
# 2                  0                5709  1549316916000        0    13539
# 3                  0                5709  1549316916000        0    28273
# 4                  0                5709  1549316916000        0    11289
# ...              ...                 ...            ...      ...      ...
# 1414603        42152              112874  1555157492000    42152    11224
# 1414604        42152              112874  1555157492000    42152     6674
# 1414605        42152              112874  1555157492000    42152    28598
# 1414606        42152              112874  1555157492000    42152     4862
# 1414607        42152              112874  1555157492000    42152    21079
#
#           response  user_id_encoded  item_id_encoded
# event_id
# 0                0                0             2431
# 1                0                0             5850
# 2                0                0             3033
# 3                0                0             6381
# 4                0                0             2523
# ...            ...              ...              ...
# 1414603          0            11905             2507
# 1414604          0            11905             1466
# 1414605          0            11905             6460
# 1414606          0            11905             1071
# 1414607          1            11905             4736
#
# [1414608 rows x 8 columns]

# %%
clicks_cnt = (
    train
    .groupby(['user_id_encoded', 'item_id_encoded'])
    .sum('response')
    .query('response > 0')
    .response
    .astype(float)
    .reset_index()
)
clicks_cnt
# Out:
#        user_id_encoded  item_id_encoded  response
# 0                    0              655       1.0
# 1                    0             1505       1.0
# 2                    1             2915       1.0
# 3                    1             2964       1.0
# 4                    1             5256       1.0
# ...                ...              ...       ...
# 85610            11905             1071       2.0
# 85611            11905             1466       1.0
# 85612            11905             4531       1.0
# 85613            11905             4736       1.0
# 85614            11905             6460       2.0
#
# [85615 rows x 3 columns]

# %%
user_item_sparse = scipy.sparse.coo_matrix(
    (clicks_cnt.response, (clicks_cnt.user_id_encoded, clicks_cnt.item_id_encoded)),
    shape=(len(user_id_enc), len(item_id_enc))
)
user_item_sparse = user_item_sparse.tocsr()
user_item_sparse
# Out:
# <11906x6539 sparse matrix of type '<class 'numpy.float64'>'
# 	with 85615 stored elements in Compressed Sparse Row format>

# %%
from implicit.als import AlternatingLeastSquares

model = AlternatingLeastSquares(
    factors=128,
    regularization=10,
    random_state=0,
    iterations=64,
)
threadpoolctl.threadpool_limits(1, "blas")

model.fit(user_item_sparse)
# Out:
# /opt/conda/lib/python3.10/site-packages/implicit/cpu/als.py:95: RuntimeWarning: OpenBLAS is configured to use 4 threads. It is highly recommended to disable its internal threadpool by setting the environment variable 'OPENBLAS_NUM_THREADS=1' or by calling 'threadpoolctl.threadpool_limits(1, "blas")'. Having OpenBLAS use a threadpool can lead to severe performance issues here.
#   check_blas_config()
#   0%|          | 0/64 [00:00<?, ?it/s]

# %%
def get_recs_for_slate(model, slate, user_item_sparse):
    slate_uid_enc = slate.user_id_encoded.iloc[0]
    try:
        rec_iid_enc, scores = model.recommend(
            userid=slate_uid_enc,
            user_items=user_item_sparse.getrow(slate_uid_enc),
            items=slate.item_id_encoded,
            N=len(slate),
            filter_already_liked_items=False,
        )
    except Exception: # cold user or item
        rec_iid_enc = slate.item_id_encoded.to_numpy()
        scores = np.random.normal(slate.shape[0])
        
    res_df = pd.DataFrame({
        'item_id_encoded': rec_iid_enc,
        'rank': scores
    }).set_index('item_id_encoded')
    
    return slate.join(res_df, on='item_id_encoded')

# %%
val = (
    pd
    .read_csv('/kaggle/input/predicting-response/test.csv')
    .set_index('event_id', verify_integrity='unique')
    .assign(response=None)
)
val
# Out:
#           session_id  recommendation_idx      timestamp  user_id  item_id  \
# event_id
# 0                  0              149235  1549216052000        0    20638
# 1                  0              149235  1549216052000        0    26217
# 2                  0              149235  1549216052000        0    21102
# 3                  0              149235  1549216052000        0    14716
# 4                  0              149235  1549216052000        0     9522
# ...              ...                 ...            ...      ...      ...
# 416555         42152              139262  1549649250000    42152    12436
# 416556         42152              139262  1549649250000    42152     7569
# 416557         42152              139262  1549649250000    42152     8369
# 416558         42152              139262  1549649250000    42152    15983
# 416559         42152              139262  1549649250000    42152     7805
#
#          response
# event_id
# 0            None
# 1            None
# 2            None
# 3            None
# 4            None
# ...           ...
# 416555       None
# 416556       None
# 416557       None
# 416558       None
# 416559       None
#
# [416560 rows x 6 columns]

# %%
for user_id in val.user_id.unique():
    if user_id not in user_id_enc:
        user_id_enc[user_id] = len(user_id_enc)
        print('new user_id:', user_id, 'encoding as', user_id_enc[user_id])
        
for item_id in val.item_id.unique():
    if item_id not in item_id_enc:
        item_id_enc[item_id] = len(item_id_enc)
        print('new item_id:', item_id, 'encoding as', item_id_enc[item_id])
        
val['user_id_encoded'] = val.user_id.map(user_id_enc)
val['item_id_encoded'] = val.item_id.map(item_id_enc)
val
# Out:
# new user_id: 529 encoding as 11906
# new user_id: 571 encoding as 11907
# new user_id: 608 encoding as 11908
# new user_id: 693 encoding as 11909
# new user_id: 1422 encoding as 11910
# new user_id: 1739 encoding as 11911
# new user_id: 4560 encoding as 11912
# new user_id: 4878 encoding as 11913
# new user_id: 5886 encoding as 11914
# new user_id: 6850 encoding as 11915
# new user_id: 6899 encoding as 11916
# new user_id: 7530 encoding as 11917
# new user_id: 7925 encoding as 11918
# new user_id: 8001 encoding as 11919
# new user_id: 8216 encoding as 11920
# new user_id: 8567 encoding as 11921
# new user_id: 8930 encoding as 11922
# new user_id: 9309 encoding as 11923
# new user_id: 9687 encoding as 11924
# new user_id: 10373 encoding as 11925
# new user_id: 11184 encoding as 11926
# new user_id: 11225 encoding as 11927
# new user_id: 11551 encoding as 11928
# new user_id: 12298 encoding as 11929
# new user_id: 12987 encoding as 11930
# new user_id: 13933 encoding as 11931
# new user_id: 15142 encoding as 11932
# new user_id: 15235 encoding as 11933
# new user_id: 15485 encoding as 11934
# new user_id: 15559 encoding as 11935
# new user_id: 15581 encoding as 11936
# new user_id: 16172 encoding as 11937
# new user_id: 16277 encoding as 11938
# new user_id: 16376 encoding as 11939
# new user_id: 18570 encoding as 11940
# new user_id: 18837 encoding as 11941
# new user_id: 19459 encoding as 11942
# new user_id: 19480 encoding as 11943
# new user_id: 19536 encoding as 11944
# new user_id: 20431 encoding as 11945
# new user_id: 21257 encoding as 11946
# new user_id: 21546 encoding as 11947
# new user_id: 21628 encoding as 11948
# new user_id: 22050 encoding as 11949
# new user_id: 22363 encoding as 11950
# new user_id: 23714 encoding as 11951
# new user_id: 24062 encoding as 11952
# new user_id: 24095 encoding as 11953
# new user_id: 24109 encoding as 11954
# new user_id: 24349 encoding as 11955
# new user_id: 24439 encoding as 11956
# new user_id: 24960 encoding as 11957
# new user_id: 25197 encoding as 11958
# new user_id: 25354 encoding as 11959
# new user_id: 25485 encoding as 11960
# new user_id: 25526 encoding as 11961
# new user_id: 25804 encoding as 11962
# new user_id: 26105 encoding as 11963
# new user_id: 26264 encoding as 11964
# new user_id: 26444 encoding as 11965
# new user_id: 26736 encoding as 11966
# new user_id: 26818 encoding as 11967
# new user_id: 27821 encoding as 11968
# new user_id: 28638 encoding as 11969
# new user_id: 30122 encoding as 11970
# new user_id: 30505 encoding as 11971
# new user_id: 30789 encoding as 11972
# new user_id: 30922 encoding as 11973
# new user_id: 30951 encoding as 11974
# new user_id: 31875 encoding as 11975
# new user_id: 33328 encoding as 11976
# new user_id: 34124 encoding as 11977
# new user_id: 34218 encoding as 11978
# new user_id: 35308 encoding as 11979
# new user_id: 36106 encoding as 11980
# new user_id: 36203 encoding as 11981
# new user_id: 36500 encoding as 11982
# new user_id: 37728 encoding as 11983
# new user_id: 37745 encoding as 11984
# new user_id: 38252 encoding as 11985
# new user_id: 38267 encoding as 11986
# new user_id: 38678 encoding as 11987
# new user_id: 40293 encoding as 11988
# new user_id: 40538 encoding as 11989
# new item_id: 11899 encoding as 6539
# new item_id: 11023 encoding as 6540
# new item_id: 16482 encoding as 6541
# new item_id: 26500 encoding as 6542
# new item_id: 28663 encoding as 6543
# new item_id: 8079 encoding as 6544
# new item_id: 6961 encoding as 6545
# new item_id: 24505 encoding as 6546
# new item_id: 6395 encoding as 6547
# new item_id: 8131 encoding as 6548
# new item_id: 10564 encoding as 6549
# new item_id: 2775 encoding as 6550
# new item_id: 13389 encoding as 6551
# new item_id: 26293 encoding as 6552
# new item_id: 27102 encoding as 6553
# new item_id: 13920 encoding as 6554
# new item_id: 8507 encoding as 6555
# new item_id: 20473 encoding as 6556
# new item_id: 1372 encoding as 6557
# new item_id: 22973 encoding as 6558
# new item_id: 25081 encoding as 6559
# new item_id: 28424 encoding as 6560
# new item_id: 15492 encoding as 6561
# new item_id: 8699 encoding as 6562
# new item_id: 27361 encoding as 6563
# new item_id: 9700 encoding as 6564
# new item_id: 9090 encoding as 6565
# new item_id: 23291 encoding as 6566
# new item_id: 19390 encoding as 6567
# new item_id: 22067 encoding as 6568
# new item_id: 2732 encoding as 6569
# new item_id: 706 encoding as 6570
# new item_id: 8968 encoding as 6571
# new item_id: 11028 encoding as 6572
# new item_id: 26467 encoding as 6573
# new item_id: 605 encoding as 6574
# new item_id: 23761 encoding as 6575
# new item_id: 9053 encoding as 6576
# new item_id: 19436 encoding as 6577
# new item_id: 16107 encoding as 6578
# new item_id: 27525 encoding as 6579
# new item_id: 15976 encoding as 6580
# new item_id: 6474 encoding as 6581
# new item_id: 21172 encoding as 6582
# new item_id: 26544 encoding as 6583
# new item_id: 13239 encoding as 6584
# new item_id: 4153 encoding as 6585
# new item_id: 22740 encoding as 6586
# new item_id: 1678 encoding as 6587
# new item_id: 19478 encoding as 6588
# new item_id: 4128 encoding as 6589
# new item_id: 21289 encoding as 6590
# new item_id: 28079 encoding as 6591
# new item_id: 21317 encoding as 6592
# new item_id: 12543 encoding as 6593
# new item_id: 7915 encoding as 6594
# new item_id: 10406 encoding as 6595
# new item_id: 4482 encoding as 6596
# new item_id: 14540 encoding as 6597
# new item_id: 14891 encoding as 6598
# new item_id: 13056 encoding as 6599
# new item_id: 2989 encoding as 6600
# new item_id: 25792 encoding as 6601
# new item_id: 12444 encoding as 6602
# new item_id: 28602 encoding as 6603
# new item_id: 6775 encoding as 6604
# new item_id: 5075 encoding as 6605
# new item_id: 23900 encoding as 6606
# new item_id: 23965 encoding as 6607
# new item_id: 11826 encoding as 6608
# new item_id: 14898 encoding as 6609
# new item_id: 5090 encoding as 6610
# new item_id: 21437 encoding as 6611
# new item_id: 21521 encoding as 6612
# new item_id: 22323 encoding as 6613
# new item_id: 25795 encoding as 6614
# new item_id: 19011 encoding as 6615
# new item_id: 6475 encoding as 6616
# new item_id: 2291 encoding as 6617
# new item_id: 3978 encoding as 6618
# new item_id: 7136 encoding as 6619
# new item_id: 20647 encoding as 6620
# new item_id: 1747 encoding as 6621
# new item_id: 2786 encoding as 6622
# new item_id: 15746 encoding as 6623
# new item_id: 23582 encoding as 6624
# new item_id: 25662 encoding as 6625
# new item_id: 2616 encoding as 6626
# new item_id: 515 encoding as 6627
# new item_id: 2799 encoding as 6628
# new item_id: 28719 encoding as 6629
# new item_id: 13946 encoding as 6630
# new item_id: 2452 encoding as 6631
# new item_id: 16099 encoding as 6632
# new item_id: 16455 encoding as 6633
# new item_id: 26535 encoding as 6634
# new item_id: 16738 encoding as 6635
# new item_id: 21829 encoding as 6636
# new item_id: 5890 encoding as 6637
# new item_id: 18219 encoding as 6638
# new item_id: 28635 encoding as 6639
# new item_id: 18523 encoding as 6640
# new item_id: 13263 encoding as 6641
# new item_id: 17430 encoding as 6642
# new item_id: 5308 encoding as 6643
# new item_id: 14048 encoding as 6644
# new item_id: 24920 encoding as 6645
# new item_id: 8835 encoding as 6646
# new item_id: 21215 encoding as 6647
# new item_id: 23997 encoding as 6648
# new item_id: 28745 encoding as 6649
# new item_id: 11918 encoding as 6650
# new item_id: 22753 encoding as 6651
# new item_id: 11880 encoding as 6652
# new item_id: 14373 encoding as 6653
# new item_id: 9306 encoding as 6654
# new item_id: 10734 encoding as 6655
# new item_id: 5337 encoding as 6656
# new item_id: 23784 encoding as 6657
# new item_id: 20322 encoding as 6658
# new item_id: 24894 encoding as 6659
# new item_id: 19042 encoding as 6660
# new item_id: 7429 encoding as 6661
# new item_id: 425 encoding as 6662
# new item_id: 12381 encoding as 6663
# new item_id: 22487 encoding as 6664
# new item_id: 16663 encoding as 6665
# new item_id: 25831 encoding as 6666
# new item_id: 28787 encoding as 6667
# new item_id: 11870 encoding as 6668
# new item_id: 4500 encoding as 6669
# new item_id: 3445 encoding as 6670
# new item_id: 234 encoding as 6671
# new item_id: 16295 encoding as 6672
# new item_id: 8494 encoding as 6673
# new item_id: 21791 encoding as 6674
# new item_id: 16967 encoding as 6675
# new item_id: 19067 encoding as 6676
# new item_id: 20091 encoding as 6677
# new item_id: 11620 encoding as 6678
# new item_id: 28872 encoding as 6679
# new item_id: 18210 encoding as 6680
# new item_id: 23795 encoding as 6681
# new item_id: 2629 encoding as 6682
# new item_id: 28741 encoding as 6683
# new item_id: 16477 encoding as 6684
# new item_id: 10377 encoding as 6685
# new item_id: 23928 encoding as 6686
# new item_id: 15711 encoding as 6687
# new item_id: 22678 encoding as 6688
# new item_id: 9304 encoding as 6689
# new item_id: 12272 encoding as 6690
# new item_id: 11815 encoding as 6691
#           session_id  recommendation_idx      timestamp  user_id  item_id  \
# event_id
# 0                  0              149235  1549216052000        0    20638
# 1                  0              149235  1549216052000        0    26217
# 2                  0              149235  1549216052000        0    21102
# 3                  0              149235  1549216052000        0    14716
# 4                  0              149235  1549216052000        0     9522
# ...              ...                 ...            ...      ...      ...
# 416555         42152              139262  1549649250000    42152    12436
# 416556         42152              139262  1549649250000    42152     7569
# 416557         42152              139262  1549649250000    42152     8369
# 416558         42152              139262  1549649250000    42152    15983
# 416559         42152              139262  1549649250000    42152     7805
#
#          response  user_id_encoded  item_id_encoded
# event_id
# 0            None                0             4648
# 1            None                0             5898
# 2            None                0             4740
# 3            None                0             3288
# 4            None                0             2110
# ...           ...              ...              ...
# 416555       None            11905             2793
# 416556       None            11905             1679
# 416557       None            11905             1862
# 416558       None            11905             3567
# 416559       None            11905             1742
#
# [416560 rows x 8 columns]

# %%
pred = (
    val
    .groupby('recommendation_idx')
    .progress_apply(
        lambda slate: get_recs_for_slate(model, slate, user_item_sparse),
        include_groups=False
    )
)
pred
# Out:
#   0%|          | 0/33899 [00:00<?, ?it/s]
#                              session_id      timestamp  user_id  item_id  \
# recommendation_idx event_id
# 16620              105025         10499  1551563617000    10499      470
#                    105026         10499  1551563617000    10499    18528
#                    105027         10499  1551563617000    10499     7494
#                    105028         10499  1551563617000    10499    26217
#                    105029         10499  1551563617000    10499     4281
# ...                                 ...            ...      ...      ...
# 163699             371574         37637  1547450684000    37637    19462
#                    371575         37637  1547450684000    37637    25404
#                    371576         37637  1547450684000    37637    28598
#                    371577         37637  1547450684000    37637    23099
#                    371578         37637  1547450684000    37637     5751
#
#                             response  user_id_encoded  item_id_encoded  \
# recommendation_idx event_id
# 16620              105025       None             2979              106
#                    105026       None             2979             4161
#                    105027       None             2979             1663
#                    105028       None             2979             5898
#                    105029       None             2979              946
# ...                              ...              ...              ...
# 163699             371574       None            10640             4389
#                    371575       None            10640             5717
#                    371576       None            10640             6460
#                    371577       None            10640             5194
#                    371578       None            10640             1272
#
#                                  rank
# recommendation_idx event_id
# 16620              105025    0.016531
#                    105026    0.002710
#                    105027    0.017831
#                    105028    0.073300
#                    105029    0.014775
# ...                               ...
# 163699             371574    0.084925
#                    371575   -0.003750
#                    371576    0.783719
#                    371577    0.900549
#                    371578    0.006661
#
# [416560 rows x 8 columns]

# %%
(
    pred
    .reset_index()
    .set_index('event_id')
    .loc[:, ['rank']]
    .sort_index()
    .to_csv('submission.csv', index=True)
)

# %%
# !head submission.csv
# Out:
# event_id,rank
# 0,0.05449310317635536
# 1,0.017722394317388535
# 2,0.017313756048679352
# 3,0.010619734413921833
# 4,0.052425384521484375
# 5,-0.0020661172457039356
# 6,0.016765877604484558
# 7,-0.005121493712067604
# 8,-0.0021899088751524687
